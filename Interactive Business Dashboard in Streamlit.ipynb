# %%
import pandas as pd

file_path = "C:/Users/DELL/OneDrive/New folder/Interactive Business Dashboard in Streamlit/Global_Superstore2.csv"

df = pd.read_csv(file_path, encoding="latin1") 
df.head()
# Out:
#    Row ID         Order ID  Order Date   Ship Date     Ship Mode Customer ID  \
# 0   32298   CA-2012-124891  31-07-2012  31-07-2012      Same Day    RH-19495
# 1   26341    IN-2013-77878    5/2/2013    7/2/2013  Second Class    JR-16210
# 2   25330    IN-2013-71249  17-10-2013  18-10-2013   First Class    CR-12730
# 3   13524  ES-2013-1579342  28-01-2013  30-01-2013   First Class    KM-16375
# 4   47221     SG-2013-4320   5/11/2013   6/11/2013      Same Day     RH-9495
#
#       Customer Name      Segment           City            State  ...  \
# 0       Rick Hansen     Consumer  New York City         New York  ...
# 1     Justin Ritter    Corporate     Wollongong  New South Wales  ...
# 2      Craig Reiter     Consumer       Brisbane       Queensland  ...
# 3  Katherine Murray  Home Office         Berlin           Berlin  ...
# 4       Rick Hansen     Consumer          Dakar            Dakar  ...
#
#          Product ID    Category Sub-Category  \
# ...

# %%
df.groupby("Region")["Sales"].sum().sort_values(ascending=False)
df.groupby("Category")["Profit"].sum()
df.groupby("Customer Name")["Sales"].sum().sort_values(ascending=False).head(10)
# Out:
# Customer Name
# Tom Ashbrook          40488.07080
# Tamara Chand          37457.33300
# Greg Tran             35550.95428
# Christopher Conant    35187.07640
# Sean Miller           35170.93296
# Bart Watters          32310.44650
# Natalie Fritzler      31781.25850
# Fred Hopkins          30400.67452
# Jane Waco             30288.45030
# Hunter Lopez          30243.56658
# Name: Sales, dtype: float64

# %%
import pandas as pd
df = pd.read_csv("Global_Superstore2.csv", encoding="latin1")
print(df.head())         
print("\nColumns in dataset:")
print(df.columns)
# Out:
#    Row ID         Order ID  Order Date   Ship Date     Ship Mode Customer ID  \
# 0   32298   CA-2012-124891  31-07-2012  31-07-2012      Same Day    RH-19495
# 1   26341    IN-2013-77878    5/2/2013    7/2/2013  Second Class    JR-16210
# 2   25330    IN-2013-71249  17-10-2013  18-10-2013   First Class    CR-12730
# 3   13524  ES-2013-1579342  28-01-2013  30-01-2013   First Class    KM-16375
# 4   47221     SG-2013-4320   5/11/2013   6/11/2013      Same Day     RH-9495
#
#       Customer Name      Segment           City            State  ...  \
# 0       Rick Hansen     Consumer  New York City         New York  ...
# 1     Justin Ritter    Corporate     Wollongong  New South Wales  ...
# 2      Craig Reiter     Consumer       Brisbane       Queensland  ...
# 3  Katherine Murray  Home Office         Berlin           Berlin  ...
# 4       Rick Hansen     Consumer          Dakar            Dakar  ...
#
#          Product ID    Category Sub-Category  \
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("Global_Superstore2.csv", encoding="latin1")


total_sales = df["Sales"].sum()
total_profit = df["Profit"].sum()

print("💰 Total Sales:", round(total_sales, 2))
print("📈 Total Profit:", round(total_profit, 2))

sales_by_cat = df.groupby("Category")["Sales"].sum().sort_values(ascending=False)

plt.figure(figsize=(6,4))
sales_by_cat.plot(kind="bar", color="skyblue", edgecolor="black")
plt.title("Sales by Category")
plt.ylabel("Sales")
plt.xticks(rotation=45)
plt.show()

profit_by_region = df.groupby("Region")["Profit"].sum().sort_values(ascending=False)

plt.figure(figsize=(6,4))
profit_by_region.plot(kind="bar", color="lightgreen", edgecolor="black")
plt.title("Profit by Region")
plt.ylabel("Profit")
plt.xticks(rotation=45)
plt.show()

top_customers = df.groupby("Customer Name")["Sales"].sum().nlargest(5)

plt.figure(figsize=(6,4))
top_customers.plot(kind="bar", color="salmon", edgecolor="black")
plt.title("Top 5 Customers by Sales")
plt.ylabel("Sales")
plt.xticks(rotation=45)
plt.show()
# Out:
# 💰 Total Sales: 12642501.91
# 📈 Total Profit: 1467457.29
